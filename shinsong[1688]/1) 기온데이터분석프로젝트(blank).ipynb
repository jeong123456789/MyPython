# %% [markdown]
# ## [ 프로젝트 1 - 기온데이터 분석 ]
# ### 1) 데이터 불러오기

# %%
import csv
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)

for row in data :
    # 아래 빈 칸에 들어갈 내용을 작성해주세요!
    print(_____)

# %% [markdown]
# ###  << 몸풀기 문제 : 기상 관측 이래 가장 더웠던 날은 몇 도였을까요? >>

# %%
import csv
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

max_temp = 0 # max_temp : 최고 기온을 기록할 저장 공간
max_temp_date = '' # max_temp_date : 최고 기온이었던 날짜를 기록할 저장 공간

for row in data :
    if row[-1] != '' :
        # 아래 빈 칸에 들어갈 내용을 작성해주세요!
        if float(________) > _____ :
            memo = float(_______)
            memo_date = _______
            
print(max_temp, max_temp_date)

# %%
import csv
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

  for row in data :
    if row[-1] != '' :
        # 아래 빈 칸에 들어갈 내용을 작성해주세요!
         max_temp = 0 
         max_temp_date = ''

# %% [markdown]
# #### tip1) split 함수 : 원하는 문자를 기준으로 문자열을 나누어 리스트로 만들어줌

# %%
s = '2018 python conference'
print(s.split())

# %%
date = '1907-10-01'
split_date = date.split('-')
print(split_date[1])
# 월만 출력하기

# %%
import csv
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

max_temp = 0
max_temp_date = ''

cnt = 0
for row in data :
    if row[-1] != '' :
        # 1995년 이전의 최고 기온을 알아보기 위한 코드를 작성해보세요.
        if int(row[0].split('-')[0]) < 1995 and float(row[-1]) > max_temp :
            max_temp = float(row[-1])
            max_temp_date = row[0]
            
print(max_temp, max_temp_date)
# Out:
# 38.4 1994-07-24

# %%
import csv
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

for row in data :
    if row[-1]
    # 역대 서울 기온 중 37도 이상이었던 날의 날짜, 최고 기온을 출력해보세요.

# %% [markdown]
# ### [ plot 함수 : 데이터를 꺽은선 그래프로 표현해줌 ]

# %%
import csv
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)
     max_temp = float(row[-1])
            max_temp_date = row[0]
# Out:
#   File "<ipython-input-3-ee375177410c>", line 5
#     max_temp = float(row[-1])
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,40])
plt.show()

# %%
import csv
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

# 역대 오늘의 서울의 최고 기온을 출력해보세요.
temperature=[]
for row in data :
    if(row[-1] !='' and (row[0].split('-')[1] == '11' and row[0].split('-')[2] == '24')):       
        temperature.append(float(row[-1]))
    
import matplotlib.pyplot as plt
plt.plot(_temperature)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-bce69bc9b15b> in <module>
#      11
#      12 import matplotlib.pyplot as plt
# ---> 13 plt.plot(_temperature)
#      14
#      15 plt.show()
#
# NameError: name '_temperature' is not defined

# %% [markdown]
# ### [ hist 함수 : 데이터를 히스트그램으로 표현해줌 ]

# %%
import matplotlib.pyplot as plt
plt.hist([1,2,3,4,4,4,4])
plt.show()

# %%
import matplotlib.pyplot as plt
import random
dice =[]
for i in range(100) : 
    dice.append(random.randint(1,6))
plt.hist(dice, bins = 2)
#bins는 막대의 갯수 만일 bins=6이라면 그래프의 형태는?
plt.show()

# %%
import csv
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

# 역대 서울의 최고 기온을 히스토그램으로 출력해보세요.
max = []

for row in data :
    if(row[-1] !=""):
        max.append(float(row[-1]))
        #print(row[-1])
    
import matplotlib.pyplot as plt
plt.hist(max, bins =100)
plt.show()

# %% [markdown]
# ### Team Mission) 알고리즘 설계하기

# %%
import csv
f = open('seoul.csv' , encoding="utf-8")
data = csv.reader(f)
next(data)

temp = [11.24]
# 내 생일의 기온 변화를 시각화해보세요.
for row in data :
    date = 11.24
    if row[-1]!=''and(row[0]) :
        if row[-1]and(row[0]) :
            temp.append(float(row[-1]))

import matplotlib.pyplot as plt
plt.plot(temp)
plt.show()

# %% [markdown]
# #### tip) 조금 더 예쁘게 표현하기

# %%
import matplotlib.pyplot as plt
import csv
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

result = []

for row in data :
    if row[-3] != '' :
        result.append(float(row[-3]))
        
plt.style.use('ggplot')
plt.figure(dpi=300)
plt.rc('font', family = 'Malgun Gothic') # Windows인 경우
# plt.rc('font', family = 'AppleGothic') # MacOS인 경우
plt.title('서울 평균 기온 히스토그램')
plt.hist(result, bins=100)
plt.savefig('서울 평균 기온 히스토그램.png')
plt.show()

# %% [markdown]
# #### mission1) 000000 시각화해보기

# %%
import matplotlib.pyplot as plt
import csv
result = []
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

for row in data :
    if row[-3] != '' and row[0].split('-')[1] == '07' :
        result.append(float(row[-3]))
plt.rc('font', family = 'Malgun Gothic') # Windows인 경우
# plt.rc('font', family = 'AppleGothic') # MacOS인 경우
plt.title('매년 11월의 기온 히스토그램')        
plt.hist(result, bins = 40)
plt.show()

# %% [markdown]
# #### mission2) 000000 시각화해보기

# %%
import matplotlib.pyplot as plt
import csv
summer = []
winter = []
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)
for row in data :
    if row[-3] != '' and row[0].split('-')[1] == '07':
        summer.append(float(row[-3]))
    if row[-3] != '' and row[0].split('-')[1] == '01' :
        winter.append(float(row[-3]))
        
plt.figure(dpi=300)
plt.hist(summer, bins = 100)
plt.hist(winter, bins = 100)
plt.show()

# %% [markdown]
# ### [  boxplot 함수 : 데이터를 boxplot(상자그림)으로 표현해줌 ]

# %%
import matplotlib.pyplot as plt
plt.boxplot([1,2,3,4,7])
plt.show()

# %% [markdown]
# #### mission3) boxplot으로 시각화해보기

# %%
import matplotlib.pyplot as plt
import csv
summer = []
winter = []
f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

for row in data :
    if row[-3] != '' and row[0].split('-')[1] == '05' :
        summer.append(float(row[-3]))
    if row[-3] != '' and row[0].split('-')[1] == '10' :
        winter.append(float(row[-3]))
        
plt.boxplot([summer,winter])
plt.show()

# %% [markdown]
# #### 4) 000000 시각화하기

# %%
import matplotlib.pyplot as plt
import csv
f = open('seoul.csv')
data = csv.reader(f)
next(data)
month = [[],[],[],[],[],[],[],[],[],[],[],[]] #12개

for row in data :
    if row[-1] != '' and row[-2] != '' :
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))
        
plt.style.use('ggplot')
plt.figure(dpi=300)
plt.boxplot(month, showfliers=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-50-57c82c126c29> in <module>
#       3 f = open('seoul.csv')
#       4 data = csv.reader(f)
# ----> 5 next(data)
#       6 month = [[],[],[],[],[],[],[],[],[],[],[],[]] #12개
#       7
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0x9c in position 8: illegal multibyte sequence

# %%
import matplotlib.pyplot as plt
import csv

f = open('seoul.csv')
data = csv.reader(f)
next(data)

month = []
for i in range(31) : 
    month.append([])

for row in data :
    if row[-1] != '' :
        if row[0].split('-')[1] == '08':
            month[int(row[0].split('-')[2])-1].append(float(row[-1]))
        
plt.style.use('ggplot')
plt.figure(dpi=300)
plt.boxplot(month, showfliers=False)
plt.xticks(rotation = 45) # x축 내용 45도 회전하기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-51-8d51599e8aa4> in <module>
#       4 f = open('seoul.csv')
#       5 data = csv.reader(f)
# ----> 6 next(data)
#       7
#       8 month = []
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0x9c in position 8: illegal multibyte sequence

# %%
import matplotlib.pyplot as plt
import csv

f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
next(data)

month = [[],[],[],[],[],[],[],[],[],[],[],[]] #12개

for row in data :
    if row[-1] != '' and row[-2] != '' :
        for i in range(1,3) :
            month[int(row[0].split('-')[1])-1].append(float(row[-i]))
    
plt.style.use('ggplot')
plt.figure(dpi=300)
plt.boxplot(month, showfliers=False)
plt.show()

# %% [markdown]
# #### 5) 000000 시각화하기

# %%
import matplotlib.pyplot as plt
import csv

f = open('seoul.csv', encoding="utf-8")
data = csv.reader(f)
month = [[],[],[],[],[],[],[],[],[],[],[],[]] #12개
next(data)
for row in data :
    if row[-1] != '' and row[-2] != '' :
        month[int(row[0].split('-')[1])-1].append(float(row[-1]) - float(row[-2]))

plt.style.use('ggplot')
plt.figure(dpi=300)
plt.boxplot(month)
# plt.boxplot(month, showfliers=False)
plt.show()

# %%
result = []
for i in range(12) :
    result.append(sum(month[i])/len(month[i]))

plt.xticks(range(1,13))
plt.plot(range(1,13), result)
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
result = []
year_list = []
f = open('seoul.csv', encoding ="utf-9")
data = csv.reader(f)
next(data)
year = 1907
s = 0
cnt = 0
for row in data :
    if row[-3] != '' :
        cnt += 1
        s += float(row[-3])
    if row[0].split('-')[0] != year and cnt > 360:
        result.append(s/cnt)
        year_list.append(year)
        year = row[0].split('-')[0]
        s = 0
        cnt = 0
plt.style.use('ggplot')
plt.figure(dpi=300)
plt.plot(year_list, result)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-56-dce7c7095249> in <module>
#       3 result = []
#       4 year_list = []
# ----> 5 f = open('seoul.csv', encoding ="utf-9")
#       6 data = csv.reader(f)
#       7 next(data)
#
# LookupError: unknown encoding: utf-9

# %% [markdown]
# #### 연습 1: 분기열 온도를 막대그래프로 나타내어 보시오.

# %% [markdown]
# #### 연습2: 1년중 1교차가를 월별로 박스그래프로 나타내고 가장 큰 달을 찾아보세요.

# %% [markdown]
# #### 연습3: 지난 20년간 연교차를 박스그래프로 표시해보고 결과에 대해서 설명해보세요.
